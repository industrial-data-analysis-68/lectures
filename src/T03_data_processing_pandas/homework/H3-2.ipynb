# %% [markdown]
# # Homework: Grouping, Apply, and Merge
#
# Complete all tasks in this notebook.
# - Write your code only in the TODO areas.
# - Keep outputs visible before submission.
# - Do not change column names unless a task asks for it.

# %% [markdown]
# ## Setup

# %%
import pandas as pd

# %% [markdown]
# ## Part 1: Grouping
# Use `groupby` operations on a mock drinks dataset.

# %%
# Mock drinks dataset
drinks = pd.DataFrame(
    {
        "country": [
            "Aland",
            "Borland",
            "Corland",
            "Dorland",
            "Eland",
            "Forland",
            "Gorland",
            "Horland",
            "Iorland",
            "Jorland",
            "Korland",
            "Lorland",
        ],
        "continent": ["AF", "EU", "AS", None, "AF", "EU", "AS", "OC", None, "SA", "NA", "OC"],
        "beer_servings": [45, 120, 80, 60, 30, 150, 95, 70, 55, 110, 130, 85],
        "wine_servings": [10, 90, 30, 20, 5, 110, 25, 35, 18, 60, 75, 28],
        "total_alcohol": [2.1, 7.8, 4.5, 3.1, 1.8, 8.2, 5.2, 3.9, 2.7, 6.4, 7.1, 4.0],
    }
)
drinks.head()

# %%
# Task 1 (10 pts)
# Fill missing values in 'continent' with 'UNKNOWN'.
# Then print the number of rows per continent

# TODO

# %%
# Task 2 (10 pts)
# Compute mean values of 'beer_servings' and 'wine_servings' by continent.

# TODO

# %%
# Task 3 (10 pts)
# For each continent, show the following for 'total_alcohol':
# mean, min, max, and count.

# TODO

# %% [markdown]
# ## Part 2: Apply
# Use function-based transformations with `apply`.

# %%
# Mock student dataset
students = pd.DataFrame(
    {
        "school": ["GP", "MS", "GP", "MS", "GP", "GP", "MS", "MS", "GP", "MS", "GP", "MS"],
        "sex": ["F", "M", "F", "M", "M", "F", "F", "M", "F", "M", "M", "F"],
        "age": [15, 16, 17, 18, 19, 17, 18, 16, 19, 20, 17, 18],
        "address": ["U", "R", "U", "U", "R", "R", "U", "R", "U", "U", "R", "U"],
        "famsize": ["GT3", "LE3", "GT3", "GT3", "LE3", "GT3", "LE3", "GT3", "GT3", "LE3", "GT3", "LE3"],
        "Pstatus": ["T", "A", "T", "T", "A", "T", "T", "A", "T", "T", "A", "T"],
        "Medu": [4, 2, 3, 1, 2, 4, 3, 2, 4, 1, 2, 3],
        "Fedu": [4, 2, 3, 1, 2, 4, 3, 2, 4, 1, 2, 3],
        "Mjob": ["teacher", "services", "health", "at_home", "other", "teacher", "services", "other", "health", "at_home", "other", "services"],
        "Fjob": ["teacher", "other", "services", "teacher", "other", "health", "teacher", "services", "other", "teacher", "services", "other"],
        "reason": ["course", "home", "reputation", "course", "other", "home", "reputation", "course", "other", "home", "reputation", "course"],
        "guardian": ["mother", "father", "mother", "mother", "father", "mother", "father", "mother", "other", "father", "mother", "other"],
    }
)
students.head()

# %%
# Capitalize values in columns 'Mjob' and 'Fjob' using a custom function + apply.
# (Example: 'teacher' -> 'TEACHER')

# TODO
def capitalizer(val):
    pass

# %%
# Create a new boolean column 'legal_drinker' (age >= 18)
# using a custom function and apply.

# TODO
def is_legal_drinker(age):
    pass

# %%
# Create a new column 'category' using row-wise apply with these rules:
# - age < 18 and sex == 'F' => 'Underage Female'
# - age < 18 and sex == 'M' => 'Underage Male'
# - age >= 18 and sex == 'F' => 'Adult Female'
# - age >= 18 and sex == 'M' => 'Adult Male'

# TODO
def categorize_by_age_and_sex(row):
    pass

# %% [markdown]
# ## Part 3: Merge
# Use `merge` to combine datasets.

# %%
raw_data_1 = {
    "subject_id": ["101", "102", "103", "104", "105"],
    "first_name": ["Noah", "Emma", "Liam", "Olivia", "Mason"],
    "last_name": ["Kim", "Tran", "Singh", "Park", "Garcia"],
}

raw_data_2 = {
    "subject_id": ["104", "105", "106", "107", "108"],
    "first_name": ["Sophia", "Ethan", "Ava", "Logan", "Mia"],
    "last_name": ["Nguyen", "Brown", "Lopez", "Davis", "Wilson"],
}

raw_data_3 = {
    "subject_id": ["101", "102", "103", "104", "106", "109"],
    "test_id": [31, 32, 33, 34, 36, 39],
}

data1 = pd.DataFrame(raw_data_1)
data2 = pd.DataFrame(raw_data_2)
data3 = pd.DataFrame(raw_data_3)

display(data1)
display(data2)
display(data3)

# %%
# Merge data1 and data3 on 'subject_id' using:
# - inner join
# - left join
# - right join
# - outer join

# TODO

# %%
# Rename 'subject_id' in data1 -> 'id1' and in data3 -> 'id3'.
# Then merge these two DataFrames by matching id1 and id3 (inner join).

# TODO
