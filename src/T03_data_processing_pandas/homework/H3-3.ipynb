# %% [markdown]
# # Homework: Pivot and Melt Operations

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Exercise 1: Temperature Data Analysis
#
# You have temperature data for different cities across different months in wide format.

# %%
# Temperature data (in Celsius)
temp_wide = pd.DataFrame({
    'City': ['Tokyo', 'London', 'Sydney', 'Mumbai'],
    'April': [14, 11, 19, 28],
    'May': [18, 15, 17, 30],
    'June': [22, 18, 14, 29]
})

display(temp_wide)

# %% [markdown]
# ### Task 1.1: Convert to Long Format
#
# Convert the temperature data from wide to long format. The resulting DataFrame should have columns: `City`, `Month`, and `Temperature`.

# %%
# Your code here
temp_long = None

# display(temp_long)

# %% [markdown]
# ### Task 1.2: Find Average Temperature by Month
#
# Using the long format data, calculate the average temperature for each month across all cities.

# %%
# Your code here
avg_temp_by_month = None

# display(avg_temp_by_month)

# %% [markdown]
# ### Task 1.3: Convert Back to Wide Format
#
# Convert the long format data back to wide format with cities as rows and months as columns.

# %%
# Your code here
temp_pivoted = None

# display(temp_pivoted)

# %% [markdown]
# ## Exercise 2: Employee Performance Metrics
#
# You have employee performance data in long format showing different metrics.

# %%
# Employee performance data
performance_data = {
    'Employee': ['Emma', 'Emma', 'Emma', 'Liam', 'Liam', 'Liam', 'Olivia', 'Olivia', 'Olivia', 'Noah', 'Noah', 'Noah'],
    'Metric': ['Projects', 'Hours', 'Rating', 'Projects', 'Hours', 'Rating', 'Projects', 'Hours', 'Rating', 'Projects', 'Hours', 'Rating'],
    'Value': [12, 160, 4.5, 15, 180, 4.8, 10, 145, 4.2, 18, 200, 4.9]
}

performance_long = pd.DataFrame(performance_data)
display(performance_long)

# %% [markdown]
# ### Task 2.1: Convert to Wide Format
#
# Convert the performance data to wide format where each employee is a row and each metric is a column.

# %%
# Your code here
performance_wide = None

# display(performance_wide)

# %% [markdown]
# ### Task 2.2: Calculate Productivity Score
#
# Using the wide format data, create a new column called `Productivity` that equals `Projects` divided by `Hours` (multiplied by 100 for readability).

# %%
# Your code here


# display(performance_wide)

# %% [markdown]
# ## Exercise 4: Store Inventory with Duplicates
#
# You have inventory data from multiple stores with duplicate entries that need to be aggregated.

# %%
# Store inventory data with multiple shipments
inventory_data = {
    'Store': ['Store_A', 'Store_B', 'Store_A', 'Store_B', 'Store_A', 'Store_B', 
              'Store_A', 'Store_B', 'Store_A', 'Store_B', 'Store_A', 'Store_B'],
    'Product': ['Laptop', 'Laptop', 'Laptop', 'Laptop', 'Phone', 'Phone', 
                'Phone', 'Phone', 'Tablet', 'Tablet', 'Tablet', 'Tablet'],
    'Quantity': [25, 30, 15, 20, 40, 35, 25, 30, 20, 15, 10, 25]
}

inventory_long = pd.DataFrame(inventory_data)
display(inventory_long)

# %% [markdown]
# ### Task 4.1: Create Pivot Table with Total Inventory
#
# Use `pivot_table()` to create a summary showing the total quantity of each product at each store. The result should have products as rows and stores as columns.

# %%
# Your code here
inventory_pivot = None

# display(inventory_pivot)

# %% [markdown]
# ### Task 4.2: Calculate Average Shipment Size
#
# Use `pivot_table()` to calculate the average shipment size (quantity per shipment) for each product at each store.

# %%
# Your code here
avg_shipment = None

# display(avg_shipment)
