# %% [markdown]
# # Data Processing with Pandas (C1-C3)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Sample Data

# %%
# Create a sample employee dataset
employee_data = {
    'Employee_ID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 101, 102],
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve', 'Frank', 'Grace', 'Hank', 'Iris', 'Jack', 'Alice', 'Bob'],
    'Department': ['Sales', 'IT', 'HR', 'Sales', 'IT', np.nan, 'HR', 'Sales', np.nan, 'IT', 'Sales', 'IT'],
    'Salary': [50000, 75000, 60000, 55000, 80000, np.nan, 62000, 52000, 65000, 77000, np.nan, 75000],
    'Years_Experience': [3, 7, 5, 4, 8, 2, 6, np.nan, np.nan, 7, 3, 7],
    'Performance_Score': [8.5, 9.0, 7.5, 8.0, 9.2, 7.8, np.nan, 8.3, 8.1, 8.9, np.nan, 9.0]
}

df = pd.DataFrame(employee_data)
print("Original Dataset:")
display(df)
# Out:
# Original Dataset:
#     Employee_ID     Name Department   Salary  Years_Experience  \
# 0           101    Alice      Sales  50000.0               3.0
# 1           102      Bob         IT  75000.0               7.0
# 2           103  Charlie         HR  60000.0               5.0
# 3           104    Diana      Sales  55000.0               4.0
# 4           105      Eve         IT  80000.0               8.0
# 5           106    Frank        NaN      NaN               2.0
# 6           107    Grace         HR  62000.0               6.0
# 7           108     Hank      Sales  52000.0               NaN
# 8           109     Iris        NaN  65000.0               NaN
# 9           110     Jack         IT  77000.0               7.0
# 10          101    Alice      Sales      NaN               3.0
# 11          102      Bob         IT  75000.0               7.0
#
#     Performance_Score
# 0                 8.5
# 1                 9.0
# 2                 7.5
# 3                 8.0
# ...

# %% [markdown]
# ## Question 1: Explore Missing Data
# Check for missing values in each column and display the count

# %%
# Your code here

# %% [markdown]
# Identify which rows have at least two missing values

# %%
# Your code here

# %% [markdown]
# ## Question 2: Handle Duplicates
#
# Identify duplicate rows based on 'Employee_ID' (keeping the first occurrence)

# %%
# Your code here

# %% [markdown]
# Count how many duplicate rows exist

# %%
# Your code here

# %% [markdown]
# Remove duplicates based on 'Employee_ID', keeping the first occurrence and store the deduplicated DataFrame in a new variable called `df_dedup`

# %%
# Your code here

# %% [markdown]
# ## Question 3: Handle Missing Values
#
# Using the deduplicated DataFrame (`df_dedup`):
#
# - Fill missing values in 'Department' with 'Unknown'
# - Fill missing values in 'Salary' with the mean salary of each department
# - Fill missing values in 'Years_Experience' with 0
# - Fill missing performance scores with the mean value of the 'Performance_Score' column
#
# Display the cleaned DataFrame

# %%
# Your code here

# %% [markdown]
# ## Question 4: Filter Data
#
# Using your cleaned DataFrame:
#
# Filter employees with Salary > 60000

# %%
# Your code here

# %% [markdown]
# Filter employees in the 'IT' department

# %%
# Your code here

# %% [markdown]
# Filter employees with Performance_Score >= 8.5

# %%
# Your code here

# %% [markdown]
# Combine filters: Find employees in 'Sales' department with Salary >= 50000 AND Performance_Score > 8.0

# %%
# Your code here

# %% [markdown]
# ## Question 5: Sort Data
#
# Using your cleaned DataFrame:
#
# Sort by Salary in descending order and display the top 3 employees

# %%
# Your code here

# %% [markdown]
# Sort by Performance_Score in descending order, then by Salary in ascending order

# %%
# Your code here

# %% [markdown]
# Find the employee with the highest Performance_Score in each department

# %%
# Your code here
