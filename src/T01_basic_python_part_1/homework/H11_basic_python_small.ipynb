# %% [markdown]
# # Homework
# ## Instructions
# - Complete the tasks in the provided Jupyter notebook file.
# - You can use any Python libraries you find necessary. (e.g., pandas, numpy)

# %% [markdown]
# ### Example 1: Sales Data Processing
# You are given a list of dictionaries representing daily sales transactions.

# %%
sales_data = [
    {"product": "Laptop", "quantity": 2, "price": 1200, "category": "Electronics"},
    {"product": "Mouse", "quantity": 5, "price": 25, "category": "Electronics"},
    {"product": "Desk", "quantity": 1, "price": 350, "category": "Furniture"},
    {"product": "Chair", "quantity": 4, "price": 150, "category": "Furniture"},
    {"product": "Monitor", "quantity": 3, "price": 300, "category": "Electronics"},
    {"product": "Keyboard", "quantity": 5, "price": 75, "category": "Electronics"},
    {"product": "Bookshelf", "quantity": 2, "price": 200, "category": "Furniture"},
    {"product": "Lamp", "quantity": 6, "price": 45, "category": "Furniture"},
    {"product": "Tablet", "quantity": 3, "price": 500, "category": "Electronics"},
    {"product": "Headphones", "quantity": 10, "price": 80, "category": "Electronics"},
]

# %%
# Calculate the total revenue for each transaction (quantity * price) and add it to each dictionary as a new key "revenue"

# %%
# Create a dictionary that groups products by category. The keys should be category names and values should be lists of product names.

# %% [markdown]
# ### Example 2: Employee Data Analysis
# You have a list of employee records with their work hours and hourly rates.

# %%
employees = [
    {"name": "John", "department": "IT", "hours": 160, "hourly_rate": 35},
    {"name": "Sarah", "department": "HR", "hours": 155, "hourly_rate": 30},
    {"name": "Mike", "department": "IT", "hours": 165, "hourly_rate": 40},
    {"name": "Emily", "department": "Sales", "hours": 170, "hourly_rate": 28},
    {"name": "David", "department": "IT", "hours": 150, "hourly_rate": 38},
    {"name": "Lisa", "department": "HR", "hours": 160, "hourly_rate": 32},
    {"name": "Tom", "department": "Sales", "hours": 175, "hourly_rate": 25},
    {"name": "Anna", "department": "Sales", "hours": 168, "hourly_rate": 27},
    {"name": "Peter", "department": "IT", "hours": 158, "hourly_rate": 42},
    {"name": "Nina", "department": "HR", "hours": 162, "hourly_rate": 31},
]

# %%
# Calculate the monthly salary for each employee (hours * hourly_rate) and create a new list with dictionaries containing name and salary.

# %%
# Create a dictionary showing the average salary for each department.
