# %% [markdown]
# # Homework 02: NumPy
#
# **Instructions:**
# - Complete all exercises below
# - Test your code to ensure it works correctly
# - Submit your completed notebook
#
# ---

# %% [markdown]
# ### Exercise 1.1: Import NumPy
# Import the NumPy library with the alias `np`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 1.2: Create Arrays
# Create a NumPy array called `numbers` containing the elements [10, 20, 30, 40, 50] and print it.

# %%
# Your code here

# %% [markdown]
# ### Exercise 1.3: Array Range
# Create a NumPy array called `even_numbers` containing all even numbers from 2 to 50 (inclusive). Print the array.

# %%
# Your code here

# %% [markdown]
# ### Exercise 1.4: 2D Array
# Create a 3x3 NumPy array with the following elements:
# ```
# |5, 10, 15|
# |20, 25, 30|
# |35, 40, 45|
# ```
# Store it in a variable called `matrix` and print it.

# %%
# Your code here

# %% [markdown]
# ### Exercise 1.5: Array Operations
# Using the `matrix` from the previous exercise:
# 1. Calculate and print the sum of all elements
# 2. Calculate and print the mean of all elements
# 3. Calculate and print the maximum value
# 4. Calculate and print the minimum value

# %%
# Your code here

# %% [markdown]
# ### Exercise 1.6: Reshaping Arrays
# Reshape the `matrix` from a 3x3 array to a 1x9 array and print the result.

# %%
# Your code here
