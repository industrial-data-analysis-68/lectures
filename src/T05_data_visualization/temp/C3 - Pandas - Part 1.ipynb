# %% [markdown]
# # Data Visualization with Pandas - Part 1

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme()

# %% [markdown]
# ## Plotting graph with plot() method

# %%
data=pd.Series(np.random.randn(1000).cumsum())

# %%
data.plot()
# Out:
# <Axes: >

# %%
df1 = pd.DataFrame(np.random.randn(100, 4),columns=list('ABCD'))

# %%
df1 = df1.cumsum()
df1.head()
# Out:
#           A         B         C         D
# 0  0.617162 -0.117656 -0.214936  0.138336
# 1  1.577758 -2.105933 -0.837940 -1.104494
# 2  0.511542 -1.055683 -2.074809 -2.778928
# 3  2.105451 -0.674905 -1.003711 -2.547411
# 4  1.331219 -1.208997 -1.715786 -3.971723

# %%
df1.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Bar Charts

# %%
df1.iloc[10].plot(kind='bar')
# Out:
# <Axes: >

# %%
df1.iloc[10].plot.bar()
# Out:
# <Axes: >

# %%
df2=pd.DataFrame(np.random.rand(7,3), columns=list("ABC"))
df2.head()
# Out:
#           A         B         C
# 0  0.378016  0.874541  0.057152
# 1  0.610482  0.988376  0.573831
# 2  0.395183  0.579612  0.728602
# 3  0.577873  0.762168  0.356830
# 4  0.322295  0.161089  0.140217

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df2.plot.barh(stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Histograms

# %%
iris=pd.read_csv("./data/iris.data", header=None)
iris.columns=["sepal_length","sepal_width", "petal_length", 
              "petal_width", "species"]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.plot.hist(alpha=0.7)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.plot.hist(alpha=1, stacked=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.plot.hist(alpha=1, stacked=True, bins=25)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris["sepal_width"].plot.hist(orientation="horizontal")
# Out:
# <Axes: xlabel='Frequency'>

# %%
iris["sepal_length"].diff().hist()
# Out:
# <Axes: >

# %%
iris.hist(color="steelblue", alpha=1, bins=20)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
iris.hist("petal_length",by="species")
# Out:
# array([[<Axes: title={'center': 'Iris-setosa'}>,
#         <Axes: title={'center': 'Iris-versicolor'}>],
#        [<Axes: title={'center': 'Iris-virginica'}>, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ## Boxplot charts

# %%
iris.plot.box()
# Out:
# <Axes: >

# %%
colors={'boxes': 'Red', 'whiskers': 'blue','medians': 'Black', 'caps': 'Green'}

# %%
iris.plot.box(color=colors)
# Out:
# <Axes: >

# %%
iris.plot.box(vert=False)
# Out:
# <Axes: >

# %%
iris.boxplot()
# Out:
# <Axes: >

# %%
plt.rcParams["figure.figsize"]=(8,8)
plt.style.use("ggplot")
iris.boxplot(by='species')
# Out:
# array([[<Axes: title={'center': 'petal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'petal_width'}, xlabel='[species]'>],
#        [<Axes: title={'center': 'sepal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'sepal_width'}, xlabel='[species]'>]],
#       dtype=object)
